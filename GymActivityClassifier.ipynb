# %%
import numpy as np
# Reading the data
print('loading the dataset')
length = 200

f1 = open("REALDISP/data_y1_test_" + str(11) + ".csv")
f5 = open("REALDISP/data_y1_test_" + str(12) + ".csv")
f6 = open("REALDISP/data_y1_test_" + str(13) + ".csv")
f7 = open("REALDISP/data_y1_test_" + str(14) + ".csv")
f8 = open("REALDISP/data_y1_test_" + str(15) + ".csv")
f9 = open("REALDISP/data_y1_test_" + str(16) + ".csv")
f3 = open("REALDISP/data_y1_test_" + str(17) + ".csv")

x1 = open("REALDISP/data_x1_test_" + str(11) + ".csv")
x5 = open("REALDISP/data_x1_test_" + str(12) + ".csv")
x6 = open("REALDISP/data_x1_test_" + str(13) + ".csv")
x7 = open("REALDISP/data_x1_test_" + str(14) + ".csv")
x8 = open("REALDISP/data_x1_test_" + str(15) + ".csv")
x9 = open("REALDISP/data_x1_test_" + str(16) + ".csv")
x3 = open("REALDISP/data_x1_test_" + str(17) + ".csv")

z1 = open("REALDISP/data_z1_test_" + str(11) + ".csv")
z5 = open("REALDISP/data_z1_test_" + str(12) + ".csv")
z6 = open("REALDISP/data_z1_test_" + str(13) + ".csv")
z7 = open("REALDISP/data_z1_test_" + str(14) + ".csv")
z8 = open("REALDISP/data_z1_test_" + str(15) + ".csv")
z9 = open("REALDISP/data_z1_test_" + str(16) + ".csv")
z3 = open("REALDISP/data_z1_test_" + str(17) + ".csv")

f2 = open("REALDISP/answers_test_" + str(11) + ".csv")
f10 = open("REALDISP/answers_test_" + str(12) + ".csv")
f11 = open("REALDISP/answers_test_" + str(13) + ".csv")
f12 = open("REALDISP/answers_test_" + str(14) + ".csv")
f13 = open("REALDISP/answers_test_" + str(15) + ".csv")
f14 = open("REALDISP/answers_test_" + str(16) + ".csv")
f4 = open("REALDISP/answers_test_" + str(17) + ".csv")
# Out:
# loading the dataset

# %%
data_train1 = np.loadtxt(fname = f1, delimiter = ',')
data_train2 = np.loadtxt(fname = f5, delimiter = ',')
data_train3 = np.loadtxt(fname = f6, delimiter = ',')
data_train4 = np.loadtxt(fname = f7, delimiter = ',')
data_train5 = np.loadtxt(fname = f8, delimiter = ',')
data_train6 = np.loadtxt(fname = f9, delimiter = ',')
data_train7 = np.loadtxt(fname = f3, delimiter = ',')

xdata_train1 = np.loadtxt(fname = x1, delimiter = ',')
xdata_train2 = np.loadtxt(fname = x5, delimiter = ',')
xdata_train3 = np.loadtxt(fname = x6, delimiter = ',')
xdata_train4 = np.loadtxt(fname = x7, delimiter = ',')
xdata_train5 = np.loadtxt(fname = x8, delimiter = ',')
xdata_train6 = np.loadtxt(fname = x9, delimiter = ',')
xdata_train7 = np.loadtxt(fname = x3, delimiter = ',')

zdata_train1 = np.loadtxt(fname = z1, delimiter = ',')
zdata_train2 = np.loadtxt(fname = z5, delimiter = ',')
zdata_train3 = np.loadtxt(fname = z6, delimiter = ',')
zdata_train4 = np.loadtxt(fname = z7, delimiter = ',')
zdata_train5 = np.loadtxt(fname = z8, delimiter = ',')
zdata_train6 = np.loadtxt(fname = z9, delimiter = ',')
zdata_train7 = np.loadtxt(fname = z3, delimiter = ',')


labels_train1 = np.loadtxt(fname = f2 , delimiter = ',')
labels_train2 = np.loadtxt(fname = f10, delimiter = ',')
labels_train3 = np.loadtxt(fname = f11, delimiter = ',')
labels_train4 = np.loadtxt(fname = f12, delimiter = ',')
labels_train5 = np.loadtxt(fname = f13, delimiter = ',')
labels_train6 = np.loadtxt(fname = f14, delimiter = ',')
labels_train7 = np.loadtxt(fname = f4, delimiter = ',')

#data_test = np.loadtxt(fname = f3, delimiter = ',')
#labels_test = np.loadtxt(fname = f4, delimiter = ',')

f1.close(); f2.close(); f3.close(); f4.close(); f5.close(); f6.close(); f7.close(); f8.close(); f9.close()
x1.close(); x3.close(); x5.close(); x6.close(); x7.close(); x8.close(); x9.close()
z1.close(); z3.close(); z5.close(); z6.close(); z7.close(); z8.close(); z9.close()
print("loading done")
# Out:
# loading done

# %%
data_dic={}
data_dic[1]=data_train1
data_dic[2]=data_train2
data_dic[3]=data_train3
data_dic[4]=data_train4
data_dic[5]=data_train5
data_dic[6]=data_train6
data_dic[7]=data_train7

datax_dic={}
datax_dic[1]=xdata_train1
datax_dic[2]=xdata_train2
datax_dic[3]=xdata_train3
datax_dic[4]=xdata_train4
datax_dic[5]=xdata_train5
datax_dic[6]=xdata_train6
datax_dic[7]=xdata_train7

dataz_dic={}
dataz_dic[1]=zdata_train1
dataz_dic[2]=zdata_train2
dataz_dic[3]=zdata_train3
dataz_dic[4]=zdata_train4
dataz_dic[5]=zdata_train5
dataz_dic[6]=zdata_train6
dataz_dic[7]=zdata_train7

# %%
np.shape(data_train6)
# Out:
# (845L, 200L)

# %%
#for i in range(1,5):
for j in range(0,844):
    y=data_dic[7]
    x=datax_dic[7]
    z=dataz_dic[7]
    np.concatenate((y[j],x[j],z[j]),axis=0)

# %%
data_train = np.concatenate((data_train1, data_train2, data_train3, data_train4, data_train5, data_train6),axis = 0)
labels_train = np.concatenate((labels_train1, labels_train2, labels_train3,labels_train4, 
                               labels_train5, labels_train6),axis = 0)

np.shape(data_train1)
data_train_X = np.array([data_train1, 
                         data_train2,
                         data_train3,
                         data_train4,
                         data_train5,
                         data_train6, data_test])
labels_train_X = np.array([labels_train1,
                           labels_train2,
                           labels_train3,
                           labels_train4,
                           labels_train5,
                           labels_train6, labels_test])

# %%
#Leave one subject out classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

knn = KNeighborsClassifier(n_neighbors=3, p=1)


labels_dic={}
labels_dic[1]=labels_train1
labels_dic[2]=labels_train2
labels_dic[3]=labels_train3
labels_dic[4]=labels_train4
labels_dic[5]=labels_train5
labels_dic[6]=labels_train6
labels_dic[7]=labels_train7

# %%
#Leave one subject out classification for x1
from sklearn.metrics import confusion_matrix
import matplotlib
import matplotlib.pyplot as plt
nl=[1,2,3,4,5,6,7]
acc=0
for x in range(1,7):
    print "iteration",
    print x
    nl.remove(x);
    data_train = np.concatenate((data_dic[nl[0]], data_dic[nl[1]], data_dic[nl[2]], data_dic[nl[3]], data_dic[nl[4]], data_dic[nl[5]]),axis = 0)
    labels_train = np.concatenate((labels_dic[nl[0]], labels_dic[nl[1]], labels_dic[nl[2]],labels_dic[nl[3]], 
                               labels_dic[nl[4]], labels_dic[nl[5]]),axis = 0)
    nl.append(x);
    knn.fit(data_train, labels_train)
    predictions = knn.predict(data_dic[x])
    print('accuracy:' + str(float(np.sum(predictions == labels_dic[x]))/float(predictions.shape[0])))
    print(classification_report(labels_dic[x], predictions, digits = 4))
    acc=acc+(float(np.sum(predictions == labels_dic[x]))/float(predictions.shape[0]));
    """
    print("Confusion Matrix:")
    confusion_matrix = confusion_matrix(labels_dic[x], predictions)
    print(confusion_matrix)
    normalised_confusion_matrix = np.array(confusion_matrix, dtype=np.float32)/np.sum(confusion_matrix)*100
    print("")
    print("Confusion matrix (normalised to % of total test data):")
    print(normalised_confusion_matrix)
    # Plot Results: 
    width = 9
    height = 9
    plt.figure(figsize=(width, height))
    plt.imshow(
        normalised_confusion_matrix, 
        interpolation='nearest', 
        cmap=plt.cm.rainbow
    )
    plt.title("Confusion matrix \n(normalised to % of total test data)")
    plt.colorbar()
    #tick_marks = np.arange(n_classes)
    #plt.xticks(tick_marks, LABELS, rotation=90)
    #plt.yticks(tick_marks, LABELS)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    """
    
acc=acc/6
print "Final average accuracy",
print acc
# Out:
# iteration 1
# accuracy:0.683925811437
#              precision    recall  f1-score   support
#
#         0.0     0.7359    0.9579    0.8324       832
#         1.0     0.2273    0.1020    0.1408        49
#         2.0     0.4286    0.2812    0.3396        32
#         3.0     0.4222    0.9048    0.5758        21
#         4.0     0.0000    0.0000    0.0000         4
#         5.0     0.0000    0.0000    0.0000         8
#         6.0     0.0000    0.0000    0.0000         8
#         7.0     1.0000    0.4444    0.6154         9
#         8.0     1.0000    0.2500    0.4000         4
#         9.0     1.0000    0.7143    0.8333        21
#        10.0     1.0000    0.0526    0.1000        19
#        11.0     0.0000    0.0000    0.0000        16
#        12.0     0.5000    0.7500    0.6000        12
#        13.0     0.0000    0.0000    0.0000        18
#        14.0     0.0000    0.0000    0.0000        11
#        15.0     0.1667    0.1000    0.1250        10
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix:")
confusion_matrix = metrics.confusion_matrix(y_test, predictions)

# %%
#Leave one subject out classification binary 
nl=[1,2,3,4,5,6,7]
acc=0
for x in range(1,7):
    print "iteration",
    print x
    nl.remove(x);
    data_train = np.concatenate((data_dic[nl[0]], data_dic[nl[1]], data_dic[nl[2]], data_dic[nl[3]], data_dic[nl[4]], data_dic[nl[5]]),axis = 0)
    labels_train = np.concatenate((labels_dic[nl[0]], labels_dic[nl[1]], labels_dic[nl[2]],labels_dic[nl[3]], 
                               labels_dic[nl[4]], labels_dic[nl[5]]),axis = 0)
    nl.append(x);
    knn.fit(data_train, labels_train)
    predictions = knn.predict(data_dic[x])
    print('accuracy:' + str(float(np.sum(predictions == labels_dic[x]))/float(predictions.shape[0])))
    print(classification_report(labels_dic[x], predictions, digits = 4))
    acc=acc+(float(np.sum(predictions == labels_dic[x]))/float(predictions.shape[0]));
    
acc=acc/6
print "Final average accuracy",
print acc
# Out:
# iteration 1
# accuracy:0.758114374034
#              precision    recall  f1-score   support
#
#         0.0     0.7450    0.9483    0.8345       832
#         1.0     0.8170    0.4156    0.5509       462
#
# avg / total     0.7707    0.7581    0.7332      1294
#
# iteration 2
# accuracy:0.780076628352
#              precision    recall  f1-score   support
#
#         0.0     0.7686    0.9443    0.8474       844
#         1.0     0.8246    0.4794    0.6063       461
#
# avg / total     0.7884    0.7801    0.7622      1305
#
# iteration 3
# accuracy:0.821693121693
#              precision    recall  f1-score   support
#
#         0.0     0.8053    0.9949    0.8901      1372
#         1.0     0.9641    0.3629    0.5273       518
#
# avg / total     0.8488    0.8217    0.7907      1890
#
# iteration 4
# accuracy:0.897556390977
#              precision    recall  f1-score   support
#
#         0.0     0.9032    0.9786    0.9393      1725
# ...

# %%
#binary classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report


knn = KNeighborsClassifier(n_neighbors=3, p=1)
knn.fit(data_train, labels_train)

predictions = knn.predict(data_train7)

#print predictions
#print labels_test
print('accuracy:' + str(float(np.sum(predictions == labels_train7))/float(predictions.shape[0])))
print(classification_report(labels_train7, predictions, digits = 4))
# Out:
# accuracy:0.812785388128
#              precision    recall  f1-score   support
#
#         0.0     0.7628    0.9781    0.8571       503
#         1.0     0.9524    0.5898    0.7285       373
#
# avg / total     0.8435    0.8128    0.8024       876

# %%
#binary classification
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(data_train,labels_train)
pred = rf.predict(data_train7)

#print pred
#print labels_test
print('accuracy:' + str(float(np.sum(pred == labels_train7))/float(pred.shape[0])))
print(classification_report(labels_train7, pred, digits = 4))
# Out:
# accuracy:0.801369863014
#              precision    recall  f1-score   support
#
#         0.0     0.7737    0.9245    0.8424       503
#         1.0     0.8618    0.6354    0.7315       373
#
# avg / total     0.8112    0.8014    0.7952       876
